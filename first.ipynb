# %% [markdown]
# <a href="https://colab.research.google.com/github/AzeemAftab2005/IITR-July26/blob/main/first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Log is the way to find power of 10 or ExP

# %%
1+1
# Out:
# 2

# %% [markdown]
# Log X base b = p
# it menas b raise to p is x

# %%
from math import *

# %%
log10(10000)
# Out:
# 4.0

# %%
log10(5)
# Out:
# 0.6989700043360189

# %%
log10(100)
# Out:
# 2.0

# %%
log(100,10)
# Out:
# 2.0

# %%
num = 9

guess = .954
10**guess
# Out:
# 9.013635670781415

# %%
high = .99
low=0.92
mid = (low+high) /2
10**mid
# Out:
# 9.01571137605957

# %%
lo = 0
hi = 10
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# 5.0
# 100000.0

# %%
n = 6
lo = 0
hi = .1
mid = (lo+hi)/2
print(mid)
print(10**mid)
# Out:
# 0.05
# 1.1220184543019633
